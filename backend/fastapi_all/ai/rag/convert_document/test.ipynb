# %%
metadata = {
    'file_name': 'file',
    'page': {
        'page1': 'hi',
        'page2': 'hi'
    }
}

# %%
metadata
# Out:
# {'file_name': 'file', 'page': {'page1': 'hi', 'page2': 'hi'}}

# %%
{
    'origin': {
        'filename': ''
    },
    'texts':{
        'prov':{
            'page_no': ''
        },
        'text': ''
    },
    'table':{
        'prov':{
            'page_no':''
        },
        'data':{
            
        }
    },
    'pages': {
        
    }
}
